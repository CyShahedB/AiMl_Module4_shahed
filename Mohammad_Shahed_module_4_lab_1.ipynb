# %% [markdown]
# <a href="https://colab.research.google.com/github/CyShahedB/AiMl_Module4_shahed/blob/main/Mohammad_Shahed_module_4_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment1 (module 4 lab 1)
# ## **Things to try**
# 1) Try this on a real dataset like the Sonar dataset or the Banknote Dataset and show the error plot.

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Taking sonar dataset

# %%
data = np.genfromtxt('/content/sonar data.csv', delimiter=',')

# %%
X = data[:, :-1]  # Features (all columns except the last one)
y = data[:, -1]   # Labels (last column)

# Assuming labels in the dataset are encoded as 0 and 1
# If they are encoded differently, adjust accordingly
y = np.where(y == 0, -1, 1)

# Now, X and y contain your features and labels, respectively

# %%
def perceptron_algo_plot(X, Y):
    '''
    train perceptron and plot the total loss in each epoch.

    :param X: data samples
    :param Y: data labels
    :return: weight vector as a numpy array
    '''
    w = np.zeros(len(X[0]))
    eta = 1
    n = 30
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w

# %%
w = perceptron_algo_plot(X, y)

# %% [markdown]
# The Error plot is as above

# %% [markdown]
# 2) Increase/decrease the learning rate to see how many iterations will be take to coverge. Does it even converge on a huge learning rate?

# %% [markdown]
# By taking learning rate as 50, It is not converging,
# For above sonar dataset, for taking large (like 50) anad small (like 0.01) learning rates it is not converging
# For large learning rate the loss obtained is large and for small learinig rate it is small

# %%
def perceptron_algo_plot_1(X, Y):
    '''
    train perceptron and plot the total loss in each epoch.

    :param X: data samples
    :param Y: data labels
    :return: weight vector as a numpy array
    '''
    w = np.zeros(len(X[0]))
    eta = 50
    n = 30
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w

# %%
w = perceptron_algo_plot_1(X, y)

# %% [markdown]
# 3) Take a toy dataset that is not linearly separable and run the perceptron algorithm on it. What happens? Note your observations. An example is given below.

# %%
import numpy as np

# Create a larger custom dataset
Toydata = np.array([
    [0.68884188, 0.3495259, 1],
    [-0.44313702, 0.5912047, 1],
    [0.67904115, -0.08308103, 0],
    [0.75597579, -0.41051294, 1],
    [-0.12316413, -0.43759043, 0],
    [0.10592705, -0.79805974, 0],
    [-0.53199587, -0.84085557, 0],
    [0.48712724, 0.63135298, 1],
    [-0.21097456, -0.95846553, 0],
    [0.64413394, -0.19615501, 0],
    [0.08275105, -0.13810845, 0],
    [-0.31065856, -0.92634487, 0],
    [0.71116027, -0.38907001, 1],
    [0.47453443, 0.6508632, 1],
    [0.14197998, -1.02028799, 0],
    [-0.57749144, -0.60716635, 0],
    [0.58897795, -0.16136487, 0],
    [-0.3383481, 0.64966134, 1],
    [-0.68263195, 0.1732406, 0],
    [-0.84396067, 0.03725748, 0],
    [0.4618187, -0.17246957, 0],
    [0.69523252, 0.43478978, 1],
    [-0.7440705, -0.55235878, 0],
    [-0.78633652, -0.4282747, 0],
    [0.59427882, 0.64984476, 1],
    [0.59897739, -0.80085849, 0],
    [0.54714116, -0.61169716, 0],
    [0.15331122, -0.80392621, 0],
    [-0.43798474, -0.93170924, 0],
    [0.49871652, 0.77504466, 1],
    [0.36010263, -0.2214326, 0],
    [-0.73652774, 0.54360566, 1],
    [0.34354084, 0.96118287, 1],
    [0.67388773, 0.30913428, 1],
    [0.41072135, 0.92235005, 1],
    [0.31768419, 0.60969507, 1],
    [-0.80465733, -0.3054682, 0],
    [-0.80121749, 0.39807449, 1],
    [0.14664643, 0.28916581, 0],
    [-0.79801818, -0.40113174, 0],
    [0.31474199, 0.29207607, 1],
    [0.27087157, 0.76219629, 1],
    [-0.08310989, 0.25997918, 1],
    [0.69724063, 0.39749976, 1],
    [0.41789924, 0.88364042, 1],
    [-0.0595133, 0.12970133, 1],
    [-0.04674967, 0.18079972, 1],
    [0.68807079, 0.4206862, 1],
    [-0.03079607, 0.42812193, 1],
    [0.17413712, 0.87003071, 1],
    [-0.09958405, 0.9751883, 1],
    [0.38073062, 0.21715821, 0],
    [-0.81116658, -0.09512398, 0],
    [0.4294741, -0.1350563, 0],
    [0.52042994, 0.79634923, 1],
    [0.39870243, -0.21076027, 0],
    [0.71078333, -0.6359874, 0],
    [-0.43727468, 0.88236054, 1],
    [0.55937651, -0.57563143, 0],
    [0.72300937, 0.09866143, 1],
    [-0.79801325, 0.50142801, 1],
    [0.73806251, -0.07113462, 0],
    [0.11286096, 0.86528245, 1],
    [-0.77190718, 0.21946465, 0],
    [0.09083118, 0.93973484, 1],
    [-0.02508495, 0.26117127, 1],
    [-0.21217548, 0.95716611, 1],
    [0.19198142, -0.92478882, 0],
    [0.10284867, -0.74822471, 0],
    [0.52876428, 0.73854334, 1],
    [0.34826025, -0.88347206, 0],
    [-0.69092992, -0.45735214, 0],
    [0.64779157, -0.66225673, 0],
    [-0.83148502, 0.4298432, 1],
    [-0.64029015, -0.60704582, 0],
    [-0.68788221, 0.30614163, 1],
    [-0.83218189, 0.1673706, 0],
    [0.19566082, 0.71920915, 1],
    [-0.30998863, 0.91287024, 1],
    [0.67603652, 0.16648985, 1],
    [0.40897765, -0.87507756, 0],
    [-0.50714235, 0.6353614, 1],
    [-0.80286165, -0.30536362, 0],
    [-0.38145114, 0.72254834, 1],
    [-0.23736834, -0.63777288, 0],
    [-0.71998999, 0.05063913, 1],
    [0.70875125, -0.4163897, 0],
    [-0.3839019, 0.4227782, 1],
    [0.51254484, 0.45646951, 1],
    [-0.8104563, 0.36945828, 1],
    [0.2070542, 0.55797211, 1],
    [0.49927643, -0.71937072, 0],
    [0.52397843, 0.33219252, 1],
    [0.20491818, -0.49566853, 0],
    [0.6184527, -0.76326424, 0],
    [-0.58855914, 0.4926951, 1],
    [0.1972004, -0.9748198, 0],
    [-0.58294978, 0.60959864, 1],
    [-0.43923402, 0.7713518, 1],
    [0.55279361, 0.640125, 1],
    [-0.58107657, -0.71837868, 0],
    [-0.10877505, -0.18075884, 0],
    [0.47506612, -0.76899736, 0],
    [-0.40987508, -0.92930915, 0],
    [0.63123824, 0.57879913, 1],
    [0.56273874, 0.11618389, 1],
    [-0.13059738, -0.76975913, 0],
    [-0.14700216, -0.01858341, 0],
    [0.24674813, -0.83245022, 0],
    [0.18697624, 0.51783426, 1],
    [-0.60161449, -0.5688941, 0],
    [-0.36957085, -0.51251399, 0],
    [0.20474835, -0.54841157, 0],
    [0.12473812, 0.86026784, 1],
    [-0.46759129, -0.79336678, 0],
    [-0.348171  , -0.87013833, 0],
    [-0.81100114, 0.32477552, 0],
    [-0.18555617, 0.20723633, 1],
    [-0.63034151, -0.2897925, 0],
    [0.60605561, 0.28585373, 1],
    [-0.7465406, -0.695844  , 0],
    [0.29524271, 0.81757807, 1],
    [0.76462509, 0.35484325, 1],
    [-0.5124973, 0.53937147, 1],
    [0.42577745, 0.80576138, 1],
])

# %%
X = Toydata[:, :-1]  # Features (all columns except the last one)
y = Toydata[:, -1]   # Labels (last column)

# Assuming labels in the dataset are encoded as 0 and 1
# If they are encoded differently, adjust accordingly
y = np.where(y == 0, -1, 1)

# Now, X and y contain your features and labels, respectively

# %%
def perceptron_algo_plot_2(X, Y):
    '''
    train perceptron and plot the total loss in each epoch.

    :param X: data samples
    :param Y: data labels
    :return: weight vector as a numpy array
    '''
    w = np.zeros(len(X[0]))
    eta = 1
    n = 60
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w) * Y[i]) <= 0:
                total_error += (np.dot(X[i], w) * Y[i])
                w = w + eta * X[i] * Y[i]
        errors.append(total_error * -1)

    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')

    return w

# %%
w = perceptron_algo_plot_2(X, y)

# %% [markdown]
# If the training data is not Linearly Separable, the perceptron algorithm will eventually repeat the same set of weights and thereby enter an infinite loop.
#
# Yes this is showing that by taking non linearly separable data the perceptron algorithm is repeating itself and entered into an infinite loop.
